# %%
with open('FOME_constants/оцифрованные графики ioffe/Si_el_1.csv', 'r') as reader:
    with open('FOME_constants/оцифрованные графики ioffe/Si_el1.csv', 'w') as writer:
        for line in reader:
            writer.write(line.replace(',','.').replace('; ', ','))

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

plt.figure(figsize=(15, 10))

########################
def nu_n(T, a, b):
    Nd = 10**-12
    Na = 0
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_el1.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b--', label='data_1')
plt.plot(xdata, nu_n(xdata, 5.23e+06, 3.13e-12), 'g--', label='Fit_2018_1')
popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [5.23e+06, 3.13e-12])
plt.plot(xdata, nu_n(xdata, *popt), 'r--', label='My fit_1: a=%5.3f, b=%10e' % tuple(popt))

#######################
def nu_n(T, a, b):
    Nd = 4 * 10**-13
    Na = 0
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_el2.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b-', label='data_2')
plt.plot(xdata, nu_n(xdata, 5.23e+06, 3.13e-12), 'g-', label='Fit_2018_2')
popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [5.23e+06, 3.13e-12])
plt.plot(xdata, nu_n(xdata, *popt), 'r-', label='My fit_2: a=%5.3f, b=%10e' % tuple(popt))

#######################
def nu_n(T, a, b):
    Nd = 1.75 * 10**16
    Na = 1.48 * 10**15
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_el3.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b:.', label='data_3')
plt.plot(xdata, nu_n(xdata, 5.23e+06, 3.13e-12), 'g:.', label='Fit_2018_3')
popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [5.23e+06, 3.13e-12])
plt.plot(xdata, nu_n(xdata, *popt), 'r:.', label='My fit_3: a=%5.3f, b=%10e' % tuple(popt))

#######################
def nu_n(T, a, b):
    Nd = 1.3 * 10**17
    Na = 2.2 * 10**15
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_el4.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b:', label='data_4')
plt.plot(xdata, nu_n(xdata, 5.23e+06, 3.13e-12), 'g:', label='Fit_2018_4')
popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [5.23e+06, 3.13e-12])
plt.plot(xdata, nu_n(xdata, *popt), 'r:', label='My fit_4: a=%5.3f, b=%10e' % tuple(popt))
#######################


plt.xlabel('T')
plt.ylabel('nu')
plt.legend()
# plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# /home/ddyak/.local/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
a = (10297934 + 3122022 + 9227120 + 3091228) / 4
b = (3.13 * 10 ** -12) + (3.13 * 10 ** -12) + (4.8 * 10 **-14) + (8.03 * 10 ** -13)
a, b
# Out:
# (6434576.0, 7.110999999999999e-12)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

plt.figure(figsize=(15, 10))

a = []
b = []

########################
def nu_n(T, a, b):
    Nd = 0
    Na = 10**-12
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_hole1.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b--', label='data_1')
# plt.plot(xdata, nu_n(xdata, 1.8e+06, 1.04e-12), 'g--', label='Fit_2018_1')
popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [1.8e+06, 1.04e-12])
plt.plot(xdata, nu_n(xdata, *popt), 'r--', label='My fit_1: a=%5.3f, b=%10e' % tuple(popt))
a.append(popt[0])
b.append(popt[1])

#######################
def nu_n(T, a, b):
    Nd = 0
    Na = 10**14
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_hole2.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b-', label='data_2')
# plt.plot(xdata, nu_n(xdata, 1.8e+06, 1.04e-12), 'g-', label='Fit_2018_2')
popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [1.8e+06, 1.04e-12])
plt.plot(xdata, nu_n(xdata, *popt), 'r-', label='My fit_2: a=%5.3f, b=%10e' % tuple(popt))
a.append(popt[0])
b.append(popt[1])
#######################
def nu_n(T, a, b):
    Nd = 2.3 * 10**15
    Na = 2.4 * 10**16
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_hole3.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b:.', label='data_3')
# plt.plot(xdata, nu_n(xdata, 1.8e+06, 1.04e-12), 'g:.', label='Fit_2018_3')
popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [1.8e+06, 1.04e-12])
plt.plot(xdata, nu_n(xdata, *popt), 'r:.', label='My fit_3: a=%5.3f, b=%10e' % tuple(popt))
a.append(popt[0])
b.append(popt[1])
#######################
def nu_n(T, a, b):
    Na = 2 * 10**17
    Nd = 4.9 * 10**15
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_hole4.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b:', label='data_4')
# plt.plot(xdata, nu_n(xdata, 1.8e+06, 1.04e-12), 'g:', label='Fit_2018_4')
popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [1.8e+06, 1.04e-12])
plt.plot(xdata, nu_n(xdata, *popt), 'r:', label='My fit_4: a=%5.3f, b=%10e' % tuple(popt))
a.append(popt[0])
b.append(popt[1])

#######################

plt.xlabel('T')
plt.ylabel('nu')
plt.legend()
# plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# /home/ddyak/.local/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
print('a', sum(a) / len(a))
print('b', sum(b) / len(b))
b
# Out:
# a 6354236.811955985
# b 2.1225882812969786e-12
# [1.04e-12, 5.383368579189808e-12, 1.225867225683808e-12, 8.411173203142988e-13]

# %%
def nu_n(T, a, b):
    Nd = 2.3 * 10**15
    Na = 2.4 * 10**16
    return a / (T**1.5 + b * (Nd + Na) * T**-1.5)

data = np.genfromtxt('FOME_constants/оцифрованные графики ioffe/Si_hole4.csv', delimiter=',')
xdata = data[:,0]
ydata = data[:,1]

plt.plot(xdata, ydata, 'b:.', label='data_3')
plt.plot(xdata, nu_n(xdata, 1.8e+06, 1.04e-12), 'r:.', label='Fit_2018_4')
plt.plot(xdata, nu_n(xdata, 6354236.2,  2.1225882812969786e-12), 'g:.', label='Fit_2019_4')
# popt, pcov = curve_fit(nu_n, xdata, ydata, p0 = [1.8e+06, 1.04e-12])
# plt.plot(xdata, nu_n(xdata, *popt), 'r:.', label='My fit_3: a=%5.3f, b=%10e' % tuple(popt))
# a.append(popt[0])
# b.append(popt[1])
plt.xlabel('T')
plt.ylabel('nu')
plt.legend()
# plt.xscale('log')
# plt.yscale('log')
plt.show()
